# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df = pd.read_csv(r"D:\development\datasets\titanic\titanicData\tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(df["Embarked"].value_counts())
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
print(pd.crosstab(df["Survived"], df["Embarked"]))
# Out:
# Embarked   C   Q    S
# Survived
# 0         62  22  182
# 1         40  24   88

# %%
surv = df[df["Survived"]==1]

# %%
sns.violinplot(x="Embarked", y="Age", hue="Survived", data=df, split=True, palette="Set1")
plt.title("Survivors By Embarked")
plt.show()

# %%
sns.countplot(x="Embarked", hue="Pclass", data=df, palette="Set2")
plt.title("Class By Embarked")
plt.xlabel("Embarked Door")
plt.ylabel("Passengers")
plt.show()
